# %% [markdown]
# # <span style="color:darkblue"> Lecture 7: Applications II - Operations with multiple datasets </span>

# %% [markdown]
# <font size="5">
#
# This class will be entirely self-directed
#
# - Learn basic commands for importing/exporting datasets
# - Practice this module's concepts in a quiz
# - More info will be posted on Canvas at the start of class

# %% [markdown]
# ## <span style="color:darkblue"> I. Import Libraries </span>

# %%
# the "numPy" library is used for mathematical operations
# the "matplotlib" library is for generating graphs
# the "pandas" library is for manipualting datasets

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## <span style="color:darkblue"> II. Importing / Exporting Datasets </span>

# %% [markdown]
# <font size = "5">
#
# There are many formats to store data out there.
#
# - So far we've only imported ".csv" files
# - Also common: Excel (".xlsx") and Stata (".dta")
# - Pandas can handle all these formats! Full list:
#
# https://pandas.pydata.org/docs/reference/io.html#

# %% [markdown]
# <font size = "5" >
#
# Read/write from CSV

# %%
# Import a CSV file (READ)
carfeatures = pd.read_csv("data/features.csv")

# Save the dataset to another csv file (WRITE)
carfeatures.to_csv("data/features_stored.csv")

# %% [markdown]
# <font size = "5">
#
# Read/write from Stata (".dta")

# %%
# Read a Stata file
carfeatures = pd.read_stata("data/features.dta")

# Write a stata file
carfeatures.to_stata("data/features_stored.dta")

# %% [markdown]
# <font size = "5">
#
# Read/write from Excel (".xlsx")

# %%
#  Read
carfeatures = pd.read_excel("data/features.xlsx")

# Write 
carfeatures.to_excel("data/features_stored.xlsx")

# Note: If the information is contained in a specifc sheet of the excel file
# carfeatures = pd.read_excel("data/features.csv",sheet_name = "Sheet1")

# %% [markdown]
# ## <span style="color:darkblue"> III. Quiz Structure </span>
#
# <font size = "5">
#
# The day of the quiz I will ...
# - Provide different datasets with yearly data
# - Give more specific instructions.
# - Below, you will see that type of questions that will be asked.
# - The idea is for you to apply known concepts to new data
# - You have 50 minutes to complete the assignment
#
# Questions
#
# (exact wording may change in quiz, but exercise will be very similar)

# %% [markdown]
# <font size = "5">
#
# (a) Create two normal random variables ...
#
#
# - Call them "vec_x" and "vec_z"
# - To generate each variable, use loc = 2, scale = 5, size = 1000
# - Plot a histogram of each variable
#     - Label the axes and title
#     - Each graph should have a different title
#
# To get full points, plot the histograms on a grid (See Lecture 6)

# %%
n = 1000
vec_x  = np.random.chisquare(df = 5, size = n)
vec_y  = np.random.chisquare(df = 1, size = n)

fig, list = plt.subplots(1,2,figsize=(8,5))
plt.tight_layout


list[0].hist(x = vec_x)
list[0].set_title("Random sample from 1000")
list[0].set_xlabel("Value")
list[0].set_ylabel("Frequency")

list[1].hist(x = vec_y)
list[1].set_title("Second Random sample from 1000")
list[1].set_xlabel("Value")
list[1].set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# <font size = "5">
#
# (b) Create a new variable "vec_y" by the formula
#
# $ y = x^2 + 2x + 5$
#
# - Use element-by-element vector multiplicaiton (no loops)
# - Produce a scatter plot of "vec_y" against "vec_x"
# - Label the axes and the title
# - Change the color to "red", "green" or "purple" (you choose)

# %%
vec_x = np.random.normal(loc = 2, scale = 5, size = 1000)

vec_y = (np.sin(vec_x)) + 2 * (vec_x) + 5

#  1.52860465e-03 3.35914601e+00 1.55175976e+02 3.67982405e-01
#  1.47753040e-02 2.14079518e+01 1.00526442e+03 3.08444064e+06
#  1.65151016e+00 7.83621695e+03 8.07371436e-07 1.61412188e-03
#  7.65880178e-05 3.70273228e+05 4.84070612e+03 1.49156217e+05
#  9.49714974e+00 5.63087197e-01 2.04752423e-03 6.58728675e+03
#  2.12960064e+06 1.45831492e+08 3.51926866e-03 1.08900486e+04
#  4.73350021e-01 4.71940500e-04 3.87856346e-02 3.23056436e+08
#  1.64614965e+01 6.59829359e+04 9.68713516e-05 1.35421562e-05
#  6.23083847e+02 1.05472083e+03 3.70520080e+04 3.50797972e-03
#  2.11402677e+00 2.65358483e-01 2.74135003e-02 2.24490768e-05
#  4.66609193e+04 2.43864882e+01 2.89049343e+03 3.62417650e+00
#  1.54974425e-02 3.57112945e+00 3.39901325e-01 2.19850642e-04]

# %% [markdown]
# <font size = "5">
#
# (c) Creates two lists with ...
#
# - The names of the datasets
# - The years of the datasets (type manually based on the dataset names)

# %%
x = pd.read_csv("data/wdi_2000.csv" )
y = pd.read_csv("data/wdi_2020.csv")

list_datasets = [x,y]

list_year = [x['year'], y['year']]

for year_df in list_year:
    for year in year_df:
        if year >= 2012:
            print("This dataset contains information from or after the year 2012")
        if year < 2012:
            print("This dataset contains information from or before the year 2012")
# Out:
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or before the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012
# This dataset contains information from or after the year 2012

# %% [markdown]
# <font size = "5">
#
# (d) Create a loop that ...
#
#
# - Goes over the list of years
# - If the year $\ge$ 2010, print the message
#
# $\qquad$ "This dataset contains information on or after 2010.
#
# - If the year $<$ 2010, print the message
#
# $\qquad$ "This dataset contains information before 2010"

# %% [markdown]
# <font size = "5">
#
# (e) Create a for loop that ...
#
# - Reads multiple ".csv" files and
# - Converts them to ".xlsx" files
# - Note: Make sure to know how to read/write in subfolders
#
# Hint: Create a new list with the ".xslx" names and use a for loop with numbering

# %%
import openpyxl

csv_files = ['data/wdi_2000.csv','data/wdi_2020.csv','data/features.csv']

for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    df.to_excel(csv_file.replace('.csv', '.xlsx'), index=False)

# %% [markdown]
# <font size = "5">
#
# (f) Create a loop that ...
#
# - Reads multiple ".csv" files
# - Creates a numeric vector by
#     - Adding/Subtracting/Mutiplying/Diving two or more variables
# - Plots a histogram of the transformed variable
#     - Numbers the figures
#     - Labels the axes
#     - Labels the title

# %%
import pandas as pd

csvlist = ["data/features.csv", "data/features_stored.csv"]
xlist = ['data/featureskun.xlsx', 'wdi_2020.xlsx']

index = 0
for x in csvlist:
  tpfile = pd.read_csv(csvlist[index])
  tpfile.to_excel(xlist[index])
  tpfile1 = tpfile.to_excel(xlist[index])
  index + index + 1

  tpfile1

index = 0
for x in csvlist:
  tpfile = pd.read_csv(csvlist[index])
  vecx = np.array(tpfile["mpg"]) # any variable
  vecy = np.array(tpfile["displacement"])
  vec = vecx+vecy
  index = index + 1

  plt.hist(vec)
  plt.xlabel("value")
  plt.ylabel("mpg times displacement")
  plt.title("graph")
  plt.show
